# %%
# import necassary files
import numpy as np
import pandas as pd
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
import random
import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import drive 
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# ### Read datasets to pandas Dataframe

# %%
# product dataset
products = pd.read_csv('/content/gdrive/MyDrive/products.csv')

# %%
# Merged file
final_file = pd.read_csv('/content/gdrive/MyDrive/merged_file1.csv')
final_file['days_since_prior_order']=final_file['days_since_prior_order'].fillna(-999)

# %% [markdown]
# ## Pick users who have ordered products more than 90 because of Memory constraint

# %%
final_file.head(2)
# Out:
#    order_id  user_id  ...  aisle_id  department_id
# 0   2539329        1  ...        77              7
# 1   2539329        1  ...        91             16
#
# [2 rows x 11 columns]

# %%
total_orders_per_user = final_file.groupby('user_id')['order_id'].nunique()

# %%
total_orders_per_user.sort_values(ascending=False)
# Out:
# user_id
# 26086     99
# 120897    99
# 122476    99
# 31118     99
# 1868      99
#           ..
# 74171      3
# 160560     3
# 160570     3
# 74147      3
# 127633     3
# Name: order_id, Length: 206209, dtype: int64

# %%
users_bought_for_90_times = total_orders_per_user.loc[lambda x:x>=90].index

# %%
len(users_bought_for_90_times)
# Out:
# 1905

# %% [markdown]
# ## Data Preparation

# %%
new_data = final_file[final_file.user_id.isin(users_bought_for_90_times)]

# %%
new_data.product_id.nunique()
# Out:
# 27638

# %%
new_data.head()
# Out:
#        order_id  user_id  ...  aisle_id  department_id
# 28176   3264342      210  ...       123              4
# 28177   3264342      210  ...        84             16
# 28178   3264342      210  ...       123              4
# 28179   3264342      210  ...       105             13
# 28180   3264342      210  ...       120             16
#
# [5 rows x 11 columns]

# %% [markdown]
# ## Create Frequent item set using Apriori

# %%
new_data1 = new_data[['order_id','product_id']]
new_data1['product_id'] = new_data1['product_id'].astype('str')

# %%
data3 = new_data1.groupby('order_id')['product_id'].apply(lambda x: list(','.join(x).split(','))).reset_index(name='product_list')

# %%
data3.head()
# Out:
#    order_id                                       product_list
# 0        15                  [19660, 21195, 7461, 2996, 32463]
# 1        50        [397, 34993, 17183, 37788, 1025, 4799, 276]
# 2        79  [4210, 4377, 39461, 13627, 13110, 12397, 4840,...
# 3        92  [21903, 24852, 21137, 49235, 35561, 1376, 2660...
# 4        95  [47766, 21137, 49683, 39928, 9337, 10121, 3763...

# %%
prod = list(data3['product_list'])
from mlxtend.preprocessing import TransactionEncoder
te = TransactionEncoder()
te_ary = te.fit_transform(prod)
df = pd.DataFrame(te_ary, columns=te.columns_)

# %%
df
# Out:
#             1     10    100   1000  10003  ...    999   9990   9993   9995   9996
# 0       False  False  False  False  False  ...  False  False  False  False  False
# 1       False  False  False  False  False  ...  False  False  False  False  False
# 2       False  False  False  False  False  ...  False  False  False  False  False
# 3       False  False  False  False  False  ...  False  False  False  False  False
# 4       False  False  False  False  False  ...  False  False  False  False  False
# ...       ...    ...    ...    ...    ...  ...    ...    ...    ...    ...    ...
# 185826  False  False  False  False  False  ...  False  False  False  False  False
# 185827  False  False  False  False  False  ...  False  False  False  False  False
# 185828  False  False  False  False  False  ...  False  False  False  False  False
# 185829  False  False  False  False  False  ...  False  False  False  False  False
# 185830  False  False  False  False  False  ...  False  False  False  False  False
#
# [185831 rows x 27638 columns]

# %%
del final_file,new_data,new_data1,prod

# %%
frequent_itemsets  = apriori(df, min_support=0.01, use_colnames=True)

# %%
frequent_itemsets.shape
# Out:
# (109, 2)

# %% [markdown]
# ## Find association rules

# %%
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1)
rules.sort_values(by='confidence',ascending=False)
# Out:
#    antecedents consequents  antecedent support  ...      lift  leverage  conviction
# 1      (19057)     (13176)            0.033272  ...  2.286358  0.005725    1.247885
# 24     (47766)     (24852)            0.036991  ...  2.445958  0.006547    1.252619
# 11     (47209)     (13176)            0.083662  ...  2.165727  0.013046    1.219535
# 9      (27966)     (13176)            0.055292  ...  2.088104  0.008048    1.201965
# 17     (27966)     (21137)            0.055292  ...  2.623299  0.008724    1.211791
# 5      (21903)     (13176)            0.071242  ...  1.686677  0.006544    1.118617
# 2      (21137)     (13176)            0.097201  ...  1.658784  0.008566    1.113253
# 19     (47209)     (21137)            0.083662  ...  1.982547  0.007990    1.118302
# 27     (27966)     (47209)            0.055292  ...  2.223056  0.005658    1.125702
# 7      (27845)     (13176)            0.054829  ...  1.368356  0.002702    1.060314
# 21     (21903)     (24852)            0.071242  ...  1.488453  0.004259    1.073107
# 10     (13176)     (47209)            0.133767  ...  2.165727  0.013046    1.119108
# 13     (21903)     (21137)            0.071242  ...  1.841711  0.005829    1.099655
# 14     (21137)     (24852)            0.097201  ...  1.435589  0.005182    1.064683
# 22     (21903)     (47209)            0.071242  ...  2.045862  0.006234    1.105568
# 18     (21137)     (47209)            0.097201  ...  1.982547  0.007990    1.098547
# 3      (13176)     (21137)            0.133767  ...  1.658784  0.008566    1.076344
# 23     (47209)     (21903)            0.083662  ...  2.045862  0.006234    1.087222
# 16     (21137)     (27966)            0.097201  ...  2.623299  0.008724    1.104983
# 15     (24852)     (21137)            0.122402  ...  1.435589  0.005182    1.049206
# 12     (21137)     (21903)            0.097201  ...  1.841711  0.005829    1.069021
# 26     (47209)     (27966)            0.083662  ...  2.223056  0.005658    1.077103
# 4      (13176)     (21903)            0.133767  ...  1.686677  0.006544    1.055602
# 8      (13176)     (27966)            0.133767  ...  2.088104  0.008048    1.068017
# 20     (24852)     (21903)            0.122402  ...  1.488453  0.004259    1.038926
# 25     (24852)     (47766)            0.122402  ...  2.445958  0.006547    1.058808
# 0      (13176)     (19057)            0.133767  ...  2.286358  0.005725    1.046324
# 6      (13176)     (27845)            0.133767  ...  1.368356  0.002702    1.021835
#
# [28 rows x 9 columns]

# %%
rules.shape
# Out:
# (28, 9)

# %%
rules['antecedents'] = rules['antecedents'].apply(lambda x: int(''.join(list(x))))
rules['consequents'] = rules['consequents'].apply(lambda x: int(''.join(list(x))))

# %%
rules = pd.merge(rules,products[['product_id','product_name']],left_on=['antecedents'], right_on='product_id').drop(['antecedents','product_id'],1)
rules = rules.rename(columns={'product_name':'antecedents'})

# %%
rules = pd.merge(rules,products[['product_id','product_name']],left_on=['consequents'], right_on='product_id').drop(['consequents','product_id'],1)
rules = rules.rename(columns={'product_name':'consequents'})

# %%
rules.sort_values(by='confidence',ascending=False)
# Out:
#     antecedent support  ...                           consequents
# 18            0.033272  ...                Bag of Organic Bananas
# 26            0.036991  ...                                Banana
# 23            0.083662  ...                Bag of Organic Bananas
# 22            0.055292  ...                Bag of Organic Bananas
# 3             0.055292  ...                  Organic Strawberries
# 20            0.071242  ...                Bag of Organic Bananas
# 19            0.097201  ...                Bag of Organic Bananas
# 4             0.083662  ...                  Organic Strawberries
# 17            0.055292  ...                  Organic Hass Avocado
# 21            0.054829  ...                Bag of Organic Bananas
# 25            0.071242  ...                                Banana
# 14            0.133767  ...                  Organic Hass Avocado
# 2             0.071242  ...                  Organic Strawberries
# 24            0.097201  ...                                Banana
# 16            0.071242  ...                  Organic Hass Avocado
# 15            0.097201  ...                  Organic Hass Avocado
# 1             0.133767  ...                  Organic Strawberries
# 8             0.083662  ...                  Organic Baby Spinach
# 12            0.097201  ...                   Organic Raspberries
# 5             0.122402  ...                  Organic Strawberries
# 7             0.097201  ...                  Organic Baby Spinach
# 13            0.083662  ...                   Organic Raspberries
# 6             0.133767  ...                  Organic Baby Spinach
# 11            0.133767  ...                   Organic Raspberries
# 9             0.122402  ...                  Organic Baby Spinach
# 27            0.122402  ...                       Organic Avocado
# 0             0.133767  ...  Organic Large Extra Fancy Fuji Apple
# 10            0.133767  ...                    Organic Whole Milk
#
# [28 rows x 9 columns]

# %% [markdown]
# - From the output above, we can see that association of two items are from the same product category (Organic).
# - A common application of association rules mining is in the domain of recommender systems. Once item pairs have been identified as having positive relationship, recommendations can be made to customers in order to increase sales.
